# %% [markdown]
# # Laboratory 1: Introduction to Qiskit
# ## From Theory to Practice: First Steps with Quantum Circuits
#
# **Objective:** This laboratory serves as the bridge between the theoretical concepts of single-qubit states and their practical implementation using Qiskit.
#
# **Learning Objectives:**
# 1. Visualize quantum states and understand the difference between Bloch Sphere and Q-Sphere.
# 2. Implement basic gates ($X, H, Z$) and observe their effect on probability amplitudes.
# 3. Run a quantum circuit and interpret "Shot Noise" in measurement results.
# 4. Demonstrate quantum interference experimentally.
#
# ---

# %% [markdown]
# ## Recap: Part A - Visual Intuition (IBM Quantum Composer)
# Before diving into code, we used the drag-and-drop interface to observe:
# * **Exercise 1 (Pauli-X):** Flips $|0\rangle$ to $|1\rangle$. Visually: moves the vector to the South Pole.
# * **Exercise 2 (Hadamard):** Creates superposition $|+\rangle = \frac{|0\rangle + |1\rangle}{\sqrt{2}}$. Visually: two blue dots on the Q-Sphere.
# * **Exercise 3 (Pauli-Z):** Flips the phase of the $|1\rangle$ component. Visually: the bottom dot on the Q-Sphere turns **Red** (Phase $\pi$).

# %% [markdown]
# ### Environment Setup
# This cell installs the necessary libraries and imports the tools we will use.

# %%
# !pip install qiskit[visualization] qiskit-aer matplotlib pylatexenc

# %%
import numpy as np
from qiskit import QuantumCircuit
from qiskit_aer import AerSimulator
from qiskit.quantum_info import Statevector
from qiskit.visualization import plot_histogram, plot_bloch_multivector, plot_state_qsphere
import matplotlib.pyplot as plt

print("\n ENVIRONMENT SETUP COMPLETE!")

# %% [markdown]
# ## Part B: Coding & Simulation
#
# ### Exercise 4: The Reality of Measurement (Shot Noise)
#
# **Theoretical Context:**
# The H gate creates the state:
# $$|+\rangle = \frac{1}{\sqrt{2}}|0\rangle + \frac{1}{\sqrt{2}}|1\rangle$$
# The probability of measuring `0` or `1` is exactly 50%. However, this is a *theoretical* probability.
#
# **Your Task:**
# Observe how the **Shot Noise** (statistical variance) decreases as you increase the number of executions ("shots").
# 1. Run the cell with `NUM_SHOTS = 50`.
# 2. Change to `1000` and then `10000` to see the convergence to the 50/50 ideal.

# %%
# --- STUDENT EXPERIMENT ZONE ---
NUM_SHOTS = 50  # Try changing this to 100, 1000, or 10000
# -------------------------------

qc = QuantumCircuit(1, 1)
qc.h(0)            
qc.measure(0, 0)   

simulator = AerSimulator()
job = simulator.run(qc, shots=NUM_SHOTS)
counts = job.result().get_counts()

print(f"Results after {NUM_SHOTS} shots: {counts}")
plot_histogram(counts)

# %% [markdown]
# ### Exercise 5: Quantum Interference (The H-Z-H Sequence)
#
# **Motivation:**
# In Exercise 3, we saw that the Z gate is "invisible" to probability (it's still 50/50).
# *How can we prove it did something?* We use **Interference**.
#
# **Your Task:**
# 1. Run the cell as is. Notice the Q-Sphere shows a **Red** dot (negative phase) but the final measurement is random (50/50) because we only have ONE H gate.
# 2. Activate the **second Hadamard** by removing the `#` at the end.
# 3. Observe: The measurement becomes deterministically `1`. The interference has converted the "invisible" phase into a "visible" bit flip!

# %%
qc_int = QuantumCircuit(1, 1)

# Step 1: Create superposition (|+> state)
qc_int.h(0)

# Step 2: Apply Phase Flip (Z gate)
qc_int.z(0)

# --- VISUALIZE BEFORE MEASUREMENT ---
state = Statevector.from_instruction(qc_int)
print("State before second H gate:")
display(plot_state_qsphere(state))

# Step 3: Close the interference loop
# --- STUDENT EXPERIMENT ZONE ---
# UNCOMMENT the line below to see interference in action
# qc_int.h(0)
# -------------------------------

qc_int.measure(0, 0)
display(qc_int.draw('mpl'))

counts = AerSimulator().run(qc_int, shots=1000).result().get_counts()
print(f"Final Measurement: {counts}")
plot_histogram(counts)
